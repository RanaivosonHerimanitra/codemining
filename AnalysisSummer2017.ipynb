# %% [markdown]
# ## import modules

# %%
import pandas as pd
import datetime
import numpy as np
from dateutil import parser
import re
from git import *

# %% [markdown]
# ### Most detailed commit history for a given repository (ActiveMQ)

# %% [markdown]
# ### load commits data

# %%
path="/home/herimanitra/Téléchargements/data-master/"
commits = pd.read_csv(path+"activemq/git2.log", sep="\u0012", header=None, names=['raw'])                    
commits.head()
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#                                                  raw
# 0  --2518bde--Fri May 5 15:43:09 2017 +0100--gtul...
# 1  10\t2\tactivemq-kahadb-store/src/main/java/org...
# 2  1\t1\tactivemq-kahadb-store/src/main/java/org/...
# 3  201\t0\tactivemq-kahadb-store/src/test/java/or...
# 4  --ae97fbd--Fri May 5 11:01:33 2017 +0100--gtul...

# %% [markdown]
# ### Format data into a useful structure

# %%
commit_marker = commits[commits['raw'].str.startswith("--")]
commit_info = commit_marker['raw'].str.extract(r"^--(?P<sha>.*?)--(?P<date>.*?)--(?P<author>.*?)--(?P<message>.*?)$", 
                                               expand=True)   
commit_info['date'] = pd.to_datetime(commit_info['date'])
file_stats_marker = commits[~commits.index.isin(commit_info.index)]
#
file_stats = file_stats_marker['raw'].str.split("\t", expand=True)
file_stats = file_stats.rename(columns={ 0: "insertions", 1: "deletions", 2: "filename"})
file_stats['insertions'] = pd.to_numeric(file_stats['insertions'], errors='coerce')
file_stats['deletions'] = pd.to_numeric(file_stats['deletions'], errors='coerce')
#
commit_info.reindex(commits.index)
#addition des statistiques
commit_data = commit_info.reindex(commits.index).fillna(method="ffill")
commit_data = commit_data[~commit_data.index.isin(commit_info.index)]
commit_data=commit_data.drop_duplicates()
commit_data = commit_data.join(file_stats)
commit_data.tail()
# Out:
#             sha                date          author  \
# 144827  ab8f458 2005-12-13 16:17:50  James Strachan
# 144829  8f40a7e 2005-12-13 16:17:31  James Strachan
# 144831  fba1488 2005-12-12 20:28:34  James Strachan
# 144836  8f1763f 2005-12-12 17:57:25  James Strachan
# 144850  40a7d3b 2005-12-12 17:53:59  James Strachan
#
#                                                   message  insertions  \
# 144827            removed old configuration documentation         0.0
# 144829            removed old configuration documentation         0.0
# 144831  updated the build so that the recursive build ...        30.0
# 144836  Moved the trunk code into the trunk sub directory         8.0
# 144850  Moved the trunk code into the trunk sub directory        20.0
#
#         deletions                                           filename
# 144827        1.0  activemq-core/src/main/resources/META-INF/serv...
# 144829        7.0  activemq-core/src/main/java/org/activemq/broke...
# 144831       13.0                           activecluster/.classpath
# 144836        0.0                          activemq-gbean/.cvsignore
# 144850        0.0                                        LICENSE.txt

# %% [markdown]
# ### finding test files

# %%
def isTest(x):
    import re
    if len(re.findall(r'/src/test/', x))>0:
        presence=1
    else:
        presence=0
    return presence
commit_data['isTest']= commit_data['filename'].apply(lambda x:isTest(x) )

# %% [markdown]
# ### Only keep java file/class:

# %%
commit_data=commit_data[commit_data['filename'].str.endswith('.java')]
commit_data = commit_data.reset_index(drop=True)
#onversion en date time
commit_data['dateT']=commit_data['date'].apply(lambda x: datetime.datetime.strftime(x, "%Y-%m-%d"))
commit_data.head()
# Out:
#        sha                date        author  \
# 0  2518bde 2017-05-05 14:43:09        gtully
# 1  b30ae4e 2017-05-05 09:47:34        gtully
# 2  bc879d7 2017-05-04 20:37:53  Timothy Bish
# 3  2e2d5dd 2017-05-04 20:37:53  Timothy Bish
# 4  dcd9b9e 2017-05-04 11:58:25        gtully
#
#                                              message  insertions  deletions  \
# 0  [AMQ-6670] - trap classcast and marshall error...        10.0        2.0
# 1    [AMQ-6665] - remove extranious import from test         0.0        1.0
# 2     https://issues.apache.org/jira/browse/AMQ-6669         5.0        0.0
# 3     https://issues.apache.org/jira/browse/AMQ-6669         5.0        0.0
# 4      use jdk8 allowed cypher in the restricted set         2.0        2.0
#
#                                             filename  isTest       dateT
# 0  activemq-kahadb-store/src/main/java/org/apache...       0  2017-05-05
# 1  activemq-unit-tests/src/test/java/org/apache/a...       1  2017-05-05
# 2  activemq-amqp/src/main/java/org/apache/activem...       0  2017-05-04
# 3  activemq-amqp/src/main/java/org/apache/activem...       0  2017-05-04
# 4  activemq-unit-tests/src/test/java/org/apache/a...       1  2017-05-04

# %% [markdown]
# ## Extract class name that are tested

# %%
commit_data_test= commit_data[commit_data["isTest"]==1]
commit_data_test=commit_data_test.reset_index()
def extract_tested_class(x):
    x1=re.compile("Test.java$").split(x)[0]
    x2= re.compile("/").split(x1)
    return x2[len(x2)-1]
commit_data_test["class"]=commit_data_test["filename"].apply(lambda x: extract_tested_class(x))
commit_data_test.head()
# Out:
#    index      sha                date  author  \
# 0      1  b30ae4e 2017-05-05 09:47:34  gtully
# 1      4  dcd9b9e 2017-05-04 11:58:25  gtully
# 2      6  2b3f0e5 2017-05-04 09:23:13  gtully
# 3      7  18d05ba 2017-05-03 15:17:29  gtully
# 4      8  35f3010 2017-05-03 11:31:09  gtully
#
#                                              message  insertions  deletions  \
# 0    [AMQ-6665] - remove extranious import from test         0.0        1.0
# 1      use jdk8 allowed cypher in the restricted set         2.0        2.0
# 2            add some logging to diagnose ci failure        19.0       14.0
# 3  modify test to validate setting isDLQ flag via...       192.0      199.0
# 4         [AMQ-2100] fix for intermittent ci failure         4.0        1.0
#
#                                             filename  isTest       dateT  \
# 0  activemq-unit-tests/src/test/java/org/apache/a...       1  2017-05-05
# 1  activemq-unit-tests/src/test/java/org/apache/a...       1  2017-05-04
# 2  activemq-mqtt/src/test/java/org/apache/activem...       1  2017-05-04
# 3  activemq-unit-tests/src/test/java/org/apache/a...       1  2017-05-03
# 4  activemq-unit-tests/src/test/java/org/apache/a...       1  2017-05-03
#
#                                  class
# 0  JaasDualAuthenticationNetworkBridge
# 1                     SslBrokerService
# 2                                 MQTT
# 3                              AMQ6059
# 4                          JMSConsumer

# %% [markdown]
# ## Extract name class from src

# %%
commit_data= commit_data[commit_data["isTest"]==0]
commit_data=commit_data.reset_index()
def extract_class(x):
    x1=re.compile(".java$").split(x)[0]
    x2= re.compile("/").split(x1)
    return x2[len(x2)-1]
commit_data["class"]=commit_data["filename"].apply(lambda x: extract_class(x))
commit_data.head()
# Out:
#    index      sha                date        author  \
# 0      0  2518bde 2017-05-05 14:43:09        gtully
# 1      2  bc879d7 2017-05-04 20:37:53  Timothy Bish
# 2      3  2e2d5dd 2017-05-04 20:37:53  Timothy Bish
# 3      5  2bd3379 2017-05-04 10:08:32        gtully
# 4     10  a0ba0bf 2017-05-03 10:36:06        gtully
#
#                                              message  insertions  deletions  \
# 0  [AMQ-6670] - trap classcast and marshall error...        10.0        2.0
# 1     https://issues.apache.org/jira/browse/AMQ-6669         5.0        0.0
# 2     https://issues.apache.org/jira/browse/AMQ-6669         5.0        0.0
# 3  [AMQ-6068] make full cleanup of the rar manage...         4.0        0.0
# 4  [AMQ-6667] gate cursor cache enablement on a s...        11.0        2.0
#
#                                             filename  isTest       dateT  \
# 0  activemq-kahadb-store/src/main/java/org/apache...       0  2017-05-05
# 1  activemq-amqp/src/main/java/org/apache/activem...       0  2017-05-04
# 2  activemq-amqp/src/main/java/org/apache/activem...       0  2017-05-04
# 3  activemq-client/src/main/java/org/apache/activ...       0  2017-05-04
# 4  activemq-broker/src/main/java/org/apache/activ...       0  2017-05-03
#
#                 class
# 0         KahaDBStore
# 1     AmqpWSTransport
# 2     AmqpWSTransport
# 3  ActiveMQConnection
# 4               Queue

# %% [markdown]
# ## merge src java with their latest respective test file

# %%
commit_data_test.columns= "test_"+commit_data_test.columns

# %%
latest_test=commit_data_test.sort_values('test_dateT', ascending=False).groupby('test_class', as_index=False).first()
latest_test=latest_test.reset_index('test_dateT',drop=True)
latest_test =latest_test.reset_index()
latest_test.head()
# Out:
#    index    test_class  test_index test_sha           test_date  \
# 0      0  AMQ1282.java        2815  5219fa1 2013-02-05 20:43:15
# 1      1       AMQ1687        3844  0e7d5a9 2011-08-11 21:17:24
# 2      2       AMQ1730        2806  600f209 2013-02-07 18:20:32
# 3      3       AMQ1853        3675  ddb15af 2011-11-18 14:23:33
# 4      4  AMQ1866.java        5589  08e01e7 2008-07-25 16:13:20
#
#         test_author                                       test_message  \
# 0   Timothy A. Bish   Fix warnings from use of deprecated asserts etc.
# 1   Timothy A. Bish     https://issues.apache.org/jira/browse/AMQ-2411
# 2   Timothy A. Bish                         Don't use hardcoded ports.
# 3   Timothy A. Bish                               Fix for NPE in test.
# 4  Hiram R. Chirino  Updating testcase.. this new version fails ver...
#
#    test_insertions  test_deletions  \
# 0             13.0             9.0
# 1              3.0             2.0
# 2             12.0            14.0
# 3             10.0             2.0
# 4             59.0            51.0
#
#                                        test_filename  test_isTest  test_dateT
# 0  activemq-unit-tests/src/test/java/org/apache/a...            1  2013-02-05
# 1  activemq-core/src/test/java/org/apache/activem...            1  2011-08-11
# 2  activemq-spring/src/test/java/org/apache/bugs/...            1  2013-02-07
# 3  activemq-core/src/test/java/org/apache/activem...            1  2011-11-18
# 4  activemq-core/src/test/java/org/apache/activem...            1  2008-07-25

# %%
commit_data= pd.merge(commit_data,latest_test,how="left",left_on="class",right_on="test_class")

# %% [markdown]
# ### Days elapsed since last change per java class (file) : One component of the ranking formula I want to build

# %%
commit_data['days_sinceLastModif']= 0
for index,obs in enumerate(range(commit_data.shape[0])):
    javaclass= commit_data['filename'][index]
    lastModif=commit_data.loc[index,'date'] 
    beforelastModif= commit_data.loc[(commit_data['filename']==
                                     javaclass) & (commit_data['date']<lastModif),['date']].max()
    #daysdiff=  datetime.datetime.now()-lastModif
    daysdiff=lastModif -beforelastModif
    commit_data.loc[index,'days_sinceLastModif'] =np.int64(daysdiff.dt.days)

# %% [markdown]
# ### Extract issue keys from commit message in commit_data

# %%
def extractKey(text):
    import re
    m = re.search('(?<=-)\w+', text)
    if m:
        found = m.group(0)
        return 'AMQ-'+found.strip()
    else:
        return ''
commit_data['Key']= commit_data['message'].apply(lambda x: extractKey(x))
commit_data.head()
# Out:
#    index_x      sha                date        author  \
# 0        0  2518bde 2017-05-05 14:43:09        gtully
# 1        2  bc879d7 2017-05-04 20:37:53  Timothy Bish
# 2        3  2e2d5dd 2017-05-04 20:37:53  Timothy Bish
# 3        5  2bd3379 2017-05-04 10:08:32        gtully
# 4       10  a0ba0bf 2017-05-03 10:36:06        gtully
#
#                                              message  insertions  deletions  \
# 0  [AMQ-6670] - trap classcast and marshall error...        10.0        2.0
# 1     https://issues.apache.org/jira/browse/AMQ-6669         5.0        0.0
# 2     https://issues.apache.org/jira/browse/AMQ-6669         5.0        0.0
# 3  [AMQ-6068] make full cleanup of the rar manage...         4.0        0.0
# 4  [AMQ-6667] gate cursor cache enablement on a s...        11.0        2.0
#
#                                             filename  isTest       dateT  \
# 0  activemq-kahadb-store/src/main/java/org/apache...       0  2017-05-05
# 1  activemq-amqp/src/main/java/org/apache/activem...       0  2017-05-04
# 2  activemq-amqp/src/main/java/org/apache/activem...       0  2017-05-04
# 3  activemq-client/src/main/java/org/apache/activ...       0  2017-05-04
# 4  activemq-broker/src/main/java/org/apache/activ...       0  2017-05-03
#
#      ...    test_date  test_author test_message  test_insertions  \
# 0    ...          NaT          NaN          NaN              NaN
# 1    ...          NaT          NaN          NaN              NaN
# 2    ...          NaT          NaN          NaN              NaN
# 3    ...          NaT          NaN          NaN              NaN
# 4    ...          NaT          NaN          NaN              NaN
#
#   test_deletions test_filename test_isTest test_dateT  days_sinceLastModif  \
# 0            NaN           NaN         NaN        NaN                  153
# 1            NaN           NaN         NaN        NaN -9223372036854775808
# 2            NaN           NaN         NaN        NaN -9223372036854775808
# 3            NaN           NaN         NaN        NaN                   28
# 4            NaN           NaN         NaN        NaN                   98
#
#         Key
# 0  AMQ-6670
# 1  AMQ-6669
# 2  AMQ-6669
# 3  AMQ-6068
# 4  AMQ-6667
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Now,Load metrics of activemq

# %% [markdown]
# ### il faudrait joindre Release-Date dans activemq-metric-history

# %%
activemq_summary= pd.read_csv(path+"activemq-summary.txt")
activemq_summary['release'] = activemq_summary[' Release-Date'].apply(lambda x: parser.parse(x))
activemq_summary.rename(columns={' Version-ID':'version'},inplace=True)
activemq_summary['version'] = activemq_summary['version'].apply(lambda x: x.strip())
activemq_summary.head()
# Out:
#    RSN version       Release-Date   #Classes   #Interfaces   #Methods  \
# 0    1   1.0M1      26-April-2004        205          1934        144
# 1    2   1.0.0     19-August-2004        368          3831        250
# 2    3   1.1.0    07-October-2004        453          4941        286
# 3    4   1.2.0   23-November-2004        467          5095        282
# 4    5   1.3.0   07-December-2004        470          5124        282
#
#     #Fields   #Size-In-Bytes    release
# 0       689           624569 2004-04-26
# 1      1385          1228417 2004-08-19
# 2      1792          1579034 2004-10-07
# 3      1806          1631249 2004-11-23
# 4      1818          1640507 2004-12-07

# %% [markdown]
# ### OO metrics et traditionnal activeMQ per release version:

# %%
activemq= pd.read_csv(path+"activemq-metric-history.txt")
activemq['Class Name']= activemq['Class Name'].apply(lambda x: x + '.java' )
activemq.tail()
# Out:
#                                                Class Name Metric Name  1.0M1  \
# 330115   org/codehaus/activemq/web/ConnectionManager.java         CCE    NaN
# 330116      org/codehaus/activemq/web/MessageServlet.java         CCE    NaN
# 330117  org/codehaus/activemq/web/MessageServletSuppor...         CCE    NaN
# 330118  org/codehaus/activemq/web/NoDestinationSupplie...         CCE    NaN
# 330119           org/codehaus/activemq/web/WebClient.java         CCE    NaN
#
#         1.0.0  1.1.0  1.2.0  1.3.0  1.4.0  1.5.0  2.0.0  ...    4.0.0  4.1.d  \
# 330115    0.0    0.0    NaN    NaN    NaN    NaN    NaN  ...      NaN    NaN
# 330116    3.0    3.0    NaN    NaN    NaN    NaN    NaN  ...      NaN    NaN
# 330117    0.0    0.0    NaN    NaN    NaN    NaN    NaN  ...      NaN    NaN
# 330118    0.0    0.0    NaN    NaN    NaN    NaN    NaN  ...      NaN    NaN
# 330119    3.0    3.0    NaN    NaN    NaN    NaN    NaN  ...      NaN    NaN
#
#         4.1.0  4.1.1  5.0.0  5.1.0  5.2.0  5.3.0  5.3.1  5.3.2
# 330115    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 330116    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 330117    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 330118    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 330119    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# [5 rows x 36 columns]

# %% [markdown]
# ### reshape variables (release version) to values

# %%
activemq= pd.melt(activemq, id_vars=['Class Name','Metric Name'], value_vars=list(activemq.columns[2:]))
activemq.rename(columns={'variable':'version','value': 'metric_value'},inplace=True)
activemq.tail()
# Out:
#                                                  Class Name Metric Name  \
# 11224075   org/codehaus/activemq/web/ConnectionManager.java         CCE
# 11224076      org/codehaus/activemq/web/MessageServlet.java         CCE
# 11224077  org/codehaus/activemq/web/MessageServletSuppor...         CCE
# 11224078  org/codehaus/activemq/web/NoDestinationSupplie...         CCE
# 11224079           org/codehaus/activemq/web/WebClient.java         CCE
#
#          version  metric_value
# 11224075   5.3.2           NaN
# 11224076   5.3.2           NaN
# 11224077   5.3.2           NaN
# 11224078   5.3.2           NaN
# 11224079   5.3.2           NaN

# %% [markdown]
# ### display some data without NaN

# %%
activemq[(activemq['version']=='1.0M1') & (activemq['metric_value'].isnull()==False) & (activemq['Metric Name']=='RFC') ].tail()
# Out:
#                                                Class Name Metric Name version  \
# 161352  org/codehaus/activemq/transport/udp/UdpTranspo...         RFC   1.0M1
# 161353  org/codehaus/activemq/transport/vm/VmTransport...         RFC   1.0M1
# 161354  org/codehaus/activemq/transport/vm/VmTransport...         RFC   1.0M1
# 161355  org/codehaus/activemq/transport/vm/VmTransport...         RFC   1.0M1
# 161356  org/codehaus/activemq/transport/vm/VmTransport...         RFC   1.0M1
#
#         metric_value
# 161352           0.0
# 161353           0.0
# 161354           0.0
# 161355           0.0
# 161356           0.0

# %% [markdown]
# ## merge release date : activemq_summary['release'] with activemq (metrics)

# %%
activemq=pd.merge(activemq,activemq_summary,how='left',on='version')
activemq=activemq[activemq['metric_value'].isnull()==False]
activemq.tail()
# Out:
#                                                  Class Name Metric Name  \
# 11223398  org/apache/activemq/wireformat/WireFormatFacto...         CCE
# 11223400   org/apache/activemq/xbean/BrokerFactoryBean.java         CCE
# 11223409  org/apache/activemq/xbean/PooledBrokerFactoryB...         CCE
# 11223410  org/apache/activemq/xbean/XBeanBrokerFactory.java         CCE
# 11223411  org/apache/activemq/xbean/XBeanBrokerService.java         CCE
#
#          version  metric_value  RSN    Release-Date   #Classes   #Interfaces  \
# 11223398   5.3.2           0.0   34   26-April-2010       1382         17354
# 11223400   5.3.2           5.0   34   26-April-2010       1382         17354
# 11223409   5.3.2           0.0   34   26-April-2010       1382         17354
# 11223410   5.3.2           0.0   34   26-April-2010       1382         17354
# 11223411   5.3.2           4.0   34   26-April-2010       1382         17354
#
#            #Methods   #Fields   #Size-In-Bytes    release
# 11223398        545      5225          5901986 2010-04-26
# 11223400        545      5225          5901986 2010-04-26
# 11223409        545      5225          5901986 2010-04-26
# 11223410        545      5225          5901986 2010-04-26
# 11223411        545      5225          5901986 2010-04-26

# %% [markdown]
# ## Change metric modality values to column of metric

# %%
X=activemq.pivot( columns='Metric Name' ,values='metric_value')
X.columns
# Out:
# Index([u'AGE', u'AMC', u'BRS', u'CAC', u'CBC', u'CC', u'CCC', u'CCE', u'CLC',
#        u'DIT', u'DMB', u'DMV', u'EC', u'EODC', u'EVD', u'EVS', u'FFC', u'FMC',
#        u'GUD', u'IAC', u'IAS', u'ICC', u'ID', u'IDC', u'IE', u'IFC', u'IGC',
#        u'II', u'IIC', u'IIN', u'IK', u'ILC', u'IM', u'IMC', u'IMN', u'INC',
#        u'INF', u'INS', u'IOC', u'IODC', u'IP', u'IR', u'ISC', u'ITC', u'JUO',
#        u'LAY', u'LFI', u'LIC', u'LMCE', u'LMCI', u'LRT', u'LVC', u'MCC',
#        u'MCE', u'MCI', u'MFR', u'MMB', u'MMC', u'MSB', u'NAC', u'NBC', u'NCN',
#        u'NOA', u'NOC', u'NOD', u'NOF', u'NOM', u'NOP', u'NVS', u'ODC', u'PFC',
#        u'PMC', u'RFC', u'RLC', u'RMC', u'RSC', u'RSZ', u'SCC', u'SFC', u'SFI',
#        u'SIC', u'SMC', u'TCC', u'THC', u'TIC', u'UFC', u'USC', u'YMC', u'ZFC',
#        u'ZOC'],
#       dtype='object', name=u'Metric Name')

# %%
activemq.columns
# Out:
# Index([u'Class Name', u'Metric Name', u'version', u'metric_value', u'RSN',
#        u' Release-Date', u' #Classes', u' #Interfaces', u' #Methods',
#        u' #Fields', u' #Size-In-Bytes', u'release'],
#       dtype='object')

# %%
for var in activemq.columns:
    if var not in X.columns:
        X[var]= activemq[var]
X.tail()
# Out:
# Metric Name  AGE  AMC  BRS  CAC  CBC  CC  CCC  CCE  CLC  DIT    ...      \
# 11223398     NaN  NaN  NaN  NaN  NaN NaN  NaN  0.0  NaN  NaN    ...
# 11223400     NaN  NaN  NaN  NaN  NaN NaN  NaN  5.0  NaN  NaN    ...
# 11223409     NaN  NaN  NaN  NaN  NaN NaN  NaN  0.0  NaN  NaN    ...
# 11223410     NaN  NaN  NaN  NaN  NaN NaN  NaN  0.0  NaN  NaN    ...
# 11223411     NaN  NaN  NaN  NaN  NaN NaN  NaN  4.0  NaN  NaN    ...
#
# Metric Name  version  metric_value  RSN    Release-Date   #Classes  \
# 11223398       5.3.2           0.0   34   26-April-2010       1382
# 11223400       5.3.2           5.0   34   26-April-2010       1382
# 11223409       5.3.2           0.0   34   26-April-2010       1382
# 11223410       5.3.2           0.0   34   26-April-2010       1382
# 11223411       5.3.2           4.0   34   26-April-2010       1382
#
# Metric Name   #Interfaces   #Methods   #Fields   #Size-In-Bytes    release
# 11223398            17354        545      5225          5901986 2010-04-26
# 11223400            17354        545      5225          5901986 2010-04-26
# 11223409            17354        545      5225          5901986 2010-04-26
# 11223410            17354        545      5225          5901986 2010-04-26
# 11223411            17354        545      5225          5901986 2010-04-26
#
# [5 rows x 102 columns]

# %% [markdown]
# ## Load issues data of activeMQ

# %%
severity1=pd.read_excel(path+"activeMQ_part1.xls")
severity1['Key']=severity1['Key'].apply(lambda x: str(x).strip())
severity2=pd.read_excel(path+"activeMQ_part2.xls")
severity2['Key']=severity2['Key'].apply(lambda x: str(x).strip())
severity3=pd.read_excel(path+"activeMQ_part3.xls")
severity3['Key']=severity3['Key'].apply(lambda x: str(x).strip())
severity4=pd.read_excel(path+"activeMQ_part4.xls")
severity4['Key']=severity4['Key'].apply(lambda x: str(x).strip())
severity5=pd.read_excel(path+"activeMQ_part5.xls")
severity5['Key']=severity5['Key'].apply(lambda x: str(x).strip())
severity=pd.concat([severity1,severity2,severity3,severity4,severity5])

# %%
cols=['Project','Key','Summary','Description','Issue Type','Status',
      'Resolution','Resolved','Creator','Created','Affects Version/s','Fix Version/s']
severity=severity.loc[severity['Project']=='ActiveMQ',cols]
severity.reset_index()
# Out:
#       index   Project       Key  \
# 0         0  ActiveMQ  AMQ-6670
# 1        12  ActiveMQ  AMQ-6669
# 2        13  ActiveMQ  AMQ-6668
# 3        14  ActiveMQ  AMQ-6667
# 4        29  ActiveMQ  AMQ-6666
# 5        67  ActiveMQ  AMQ-6665
# 6        88  ActiveMQ  AMQ-6664
# 7       113  ActiveMQ  AMQ-6663
# 8       218  ActiveMQ  AMQ-6662
# 9       270  ActiveMQ  AMQ-6661
# 10      271  ActiveMQ  AMQ-6660
# 11      333  ActiveMQ  AMQ-6659
# 12      336  ActiveMQ  AMQ-6658
# 13      390  ActiveMQ  AMQ-6657
# 14      414  ActiveMQ  AMQ-6656
# 15      470  ActiveMQ  AMQ-6655
# 16      510  ActiveMQ  AMQ-6654
# 17      531  ActiveMQ  AMQ-6653
# 18      533  ActiveMQ  AMQ-6652
# 19      535  ActiveMQ  AMQ-6651
# 20      536  ActiveMQ  AMQ-6650
# 21      564  ActiveMQ  AMQ-6649
# 22      570  ActiveMQ  AMQ-6648
# 23      583  ActiveMQ  AMQ-6647
# 24      584  ActiveMQ  AMQ-6646
# 25      585  ActiveMQ  AMQ-6645
# 26      586  ActiveMQ  AMQ-6644
# 27      627  ActiveMQ  AMQ-6643
# 28      628  ActiveMQ  AMQ-6642
# 29      629  ActiveMQ  AMQ-6641
# ...     ...       ...       ...
# 4970  20682  ActiveMQ  AMQ-1610
# 4971  20685  ActiveMQ  AMQ-1609
# 4972  20692  ActiveMQ  AMQ-1608
# 4973  20707  ActiveMQ  AMQ-1607
# 4974  20716  ActiveMQ  AMQ-1606
# 4975  20717  ActiveMQ  AMQ-1605
# 4976  20744  ActiveMQ  AMQ-1604
# 4977  20750  ActiveMQ  AMQ-1603
# 4978  20789  ActiveMQ  AMQ-1602
# 4979  20790  ActiveMQ  AMQ-1601
# 4980  20829  ActiveMQ  AMQ-1600
# 4981  20830  ActiveMQ  AMQ-1599
# 4982  20971  ActiveMQ  AMQ-1598
# 4983  20974  ActiveMQ  AMQ-1597
# 4984  20975  ActiveMQ  AMQ-1596
# 4985  21000  ActiveMQ  AMQ-1595
# 4986  21001  ActiveMQ  AMQ-1594
# 4987  21053  ActiveMQ  AMQ-1593
# 4988  21067  ActiveMQ  AMQ-1592
# 4989  21108  ActiveMQ  AMQ-1591
# 4990  21109  ActiveMQ  AMQ-1590
# 4991  21114  ActiveMQ  AMQ-1589
# 4992  21165  ActiveMQ  AMQ-1588
# 4993  21367  ActiveMQ  AMQ-1587
# 4994  21375  ActiveMQ  AMQ-1586
# 4995  21376  ActiveMQ  AMQ-1585
# 4996  21655  ActiveMQ  AMQ-1584
# 4997  21658  ActiveMQ  AMQ-1583
# 4998  21704  ActiveMQ  AMQ-1582
# 4999  21716  ActiveMQ  AMQ-1581
#
#                                                 Summary  \
# 0     KahaDB - Inconsistent error handling on corrup...
# 1     AMQP: WS connections don't respect maxFrameSiz...
# 2     Broker not created by activemq.xml file on off...
# 3     Many instances of "duplicate message ... from ...
# 4         Failover Transport - send timeout not working
# 5     certificate-based authentication on network br...
# 6     XMLs in ActiveMQ admin panel are not generated...
# 7     IO exceptions causing Broker Service shutdown;...
# 8     NullPointerException in org.apache.activemq.br...
# 9     Auto transport with MQTT will fail for a long ...
# 10    Deadlock closing a connection due to an exception
# 11    AMQP: Match client SenderSettleMode instead of...
# 12    Messenger does not respect order after redelivery
# 13    ActiveMQ does not respect sender and receiver ...
# 14               Error at AMQ Admin Panel scheduled.jsp
# 15                  Duplicated geronimo-jta spec in pom
# 16    Durable subscriber pendingQueueSize not flushe...
# 17    Rest Documentation gives Wrong Name of Timeout...
# 18    KahaDB checkpoint index page flush skips metad...
# 19    Add new implementations of the writeUTF8 and r...
# 20      Failed to auto-create database at MS SQL Server
# 21        Add support for MS SQL server JDBC driver 6.1
# 22    Async error occurred: java.lang.IllegalStateEx...
# 23    Hanging threads when InvalidClientIDException ...
# 24    default blob strategy error reporting should i...
# 25    activemq:browse command does not display Heade...
# 26    Incorrect logging from KahaDB cleanup task whe...
# 27    Shared virtual topic wildcard consumers receiv...
# 28    MessageStore update message can encounter NPE ...
# 29    Not able use Old data when we upgrade to new v...
# ...                                                 ...
# 4970  Can't receiving all send message from queue if...
# 4971  AMQNET-42 STOMP messages only support properti...
# 4972  diagnostics: "Waiting for transport to reconne...
# 4973         Static method to register TransportFactory
# 4974  The Producer MemoryLimit can lead to network d...
# 4975  5.0.0: applet fails to initialize with default...
# 4976  Please make the following configuration change...
# 4977  AMQ-1538 EOFExceptions and Broken Pipe excepti...
# 4978  Missing logging-commons.jar contents in active...
# 4979  maximumRedeliveries not honoured when transact...
# 4980  Number of items in Topic queue never empties o...
# 4981  Client deadlock after IllegalMonitorStateExcep...
# 4982  Extraneous Thread.dumpStack() method in Produc...
# 4983                            Upgrade to Jettison 1.0
# 4984  In 5.1-SNAPSHOTs, duplicate messages sent afte...
# 4985  java.lang.OutOfMemoryError when restarting a b...
# 4986  Closing an ActiveMQ connection causes 1.5 JVM ...
# 4987  redeliveryCounter not updated correctly when u...
# 4988  Inactivity Monitor: org.apache.activemq.transp...
# 4989  When using a JDBC based database locker in an ...
# 4990  Setting advisory support compromises network o...
# 4991  rss and atom feeds cause "missing ConnectionFa...
# 4992  Serialized ObjectMessages throw javax.jms.JMSE...
# 4993  Improvements/Bug Fixes for LDAP Discovery Mech...
# 4994  Topic throughput drops with the number of cons...
# 4995      Problems with pure master/slave configuration
# 4996  AMQ-2237 ClassLoadingAwareObjectInputStream ca...
# 4997  Creating a durable subscriber throws Concurren...
# 4998  If InactivityMonitor is inactive, exception no...
# 4999  PooledConnections don't initialize correctly w...
#
#                                             Description   Issue Type  \
# 0     When the journal is corrupt, for example if it...          Bug
# 1     For AMQP WebSocket connections the maxFrameSiz...          Bug
# 2     If the PC is not connected to internet, during...          Bug
# 3     In a high throughput scenario on a single dest...          Bug
# 4     Running into a situation with the Failover Tra...          Bug
# 5     client certificate authentication works in the...          Bug
# 6     Start ActiveMQ 5.14.5 and go to http://127.0.0...          Bug
# 7                ActiveMQ version: 5.11.0.redhat-620143          Bug
# 8     My company's application uses JMX with ActiveM...          Bug
# 9     The issue is that there is a variable length h...          Bug
# 10    While recovering from a period of network inst...          Bug
# 11    On link attach we currently default out Sender...  Improvement
# 12    I am facing a situation where activemq seems n...          Bug
# 13                               Here is the long story          Bug
# 14    While accessing ActiveMQ Admin Panel section S...          Bug
# 15    For sub module: activemq-jms-pool have duplica...          Bug
# 16    This is related to AMQ-5960, marked as fixed, ...          Bug
# 17       In the documentation of REST API for ActiveMQ,          Bug
# 18    Disk image of the metadata is one checkpoint b...          Bug
# 19    Provide implementation based on Apache Harmony...  Improvement
# 20    ActiveMQ generates invalid DDL for MS SQL Serv...          Bug
# 21    activemq-jdbc-store-5.14.4.jar contains suppor...          Bug
# 22    Large amounts of data to the last part of the ...          Bug
# 23    We found an issue with hanging threads when co...          Bug
# 24    Default blob upload strategy can do a little b...          Bug
# 25    The jmx view correctly exposes the originaDest...          Bug
# 26    When KahaDB is configured for enableAckCompact...          Bug
# 27    Virtual topic wildcard subscriber queues are p...          Bug
# 28    If KahaDB subscription statistics have been en...          Bug
# 29    We have upgraded Activemq 5.10. 0 to 5.14.0. W...          Bug
# ...                                                 ...          ...
# 4970  I'm running a basic instance of AMQ 5.0.0 with...          Bug
# 4971  Currently the STOMP connector seems to support...  Improvement
# 4972                              Have messages in log:  Improvement
# 4973                                Need static method:  Improvement
# 4974                                                NaN          Bug
# 4975  We are unable to create a JMS-aware applet bec...          Bug
# 4976                                                NaN          Bug
# 4977  I keep getting these errors when any of my ser...          Bug
# 4978  Missing the contents of logging-commons.jar in...          Bug
# 4979               1) Unzip attachment into a directory          Bug
# 4980  If I create a topic and then have a producer w...          Bug
# 4981  The server threw an IllegalMonitorStateExcepti...          Bug
# 4982  There is an extraneous Thread.dumpStack() call...          Bug
# 4983  1.0 final is released with a lot of bug fixes,...  Improvement
# 4984  I am seeing duplicate messages delivered after...          Bug
# 4985                                                NaN          Bug
# 4986  When I call "closeConnection()" (see below) af...          Bug
# 4987  When using ActiveMQ 5 in combination with XA, ...          Bug
# 4988                           From a different poster:          Bug
# 4989  The lockKeepAlivePeriod field was intialized t...          Bug
# 4990  The documentation pertaining to advisorySuppor...          Bug
# 4991  For queues (only tested with TextMessage and O...          Bug
# 4992     Producing and sending ObjectMessages such as..          Bug
# 4993  These are much needed improvements and bug fix...  Improvement
# 4994  If many consumers are reading from a topic, th...          Bug
# 4995                   As posted in the AMQ user forum:          Bug
# 4996  When deserializing a message contents the Clas...          Bug
# 4997  My JMS application uses a single topic and few...          Bug
# 4998  Since it is mantory to use a provider URL like...          Bug
# 4999  In working with PooledConnections, I've found ...          Bug
#
#         Status        Resolution         Resolved                 Creator  \
# 0     Resolved             Fixed  05/May/17 14:46              Gary Tully
# 1     Resolved             Fixed  04/May/17 20:55            Timothy Bish
# 2     Resolved         Duplicate  03/May/17 17:15          Giuseppe Gerla
# 3     Resolved             Fixed  03/May/17 10:43              Gary Tully
# 4         Open        Unresolved              NaN          Martin Lichtin
# 5     Resolved             Fixed  27/Apr/17 11:10              Gary Tully
# 6         Open        Unresolved              NaN                Jacek K.
# 7         Open        Unresolved              NaN              Vidyashree
# 8         Open        Unresolved              NaN              Dan Groves
# 9     Resolved             Fixed  25/Apr/17 12:47  Christopher L. Shannon
# 10        Open        Unresolved              NaN              Dan Groves
# 11    Resolved             Fixed  21/Apr/17 14:54            Timothy Bish
# 12        Open        Unresolved              NaN         Fabian González
# 13      Closed         Not A Bug  19/Apr/17 18:23            Ilya Lebedev
# 14        Open        Unresolved              NaN        Michał Sopliński
# 15        Open        Unresolved              NaN              Terence Yi
# 16        Open        Unresolved              NaN            Justin Reock
# 17        Open        Unresolved              NaN         Mike Richardson
# 18    Resolved             Fixed  10/Apr/17 16:19              Gary Tully
# 19    Resolved             Fixed  17/Apr/17 11:42           Dejan Bosanac
# 20        Open        Unresolved              NaN              Josef Brož
# 21    Resolved             Fixed  10/Apr/17 12:53              Josef Brož
# 22      Closed           Invalid  11/Apr/17 13:36                   lewis
# 23      Closed        Incomplete  05/May/17 13:58            Pavel Spatny
# 24    Resolved             Fixed  05/Apr/17 10:02              Gary Tully
# 25    Resolved             Fixed  04/Apr/17 14:09              Gary Tully
# 26    Resolved             Fixed  04/Apr/17 11:22              Gary Tully
# 27    Resolved             Fixed  04/Apr/17 09:20              Gary Tully
# 28    Resolved             Fixed  31/Mar/17 13:10  Christopher L. Shannon
# 29      Closed           Invalid  05/Apr/17 20:26           Ramakrishna K
# ...        ...               ...              ...                     ...
# 4970    Closed        Incomplete  30/Sep/11 20:38            Thomas Weise
# 4971  Resolved             Fixed  13/Aug/11 22:35          Michael Justin
# 4972    Closed     Not A Problem  16/Jan/10 20:20          Stepan Koltsov
# 4973  Resolved             Fixed  09/Apr/08 11:46          Stepan Koltsov
# 4974  Resolved             Later  02/Nov/13 20:08           Hiram Chirino
# 4975    Closed     Not A Problem  01/Jul/11 20:00              Bear Giles
# 4976  Resolved             Fixed  27/Feb/11 21:42           Denis Abramov
# 4977  Resolved             Fixed  09/Apr/08 08:40           Denis Abramov
# 4978  Resolved             Fixed  28/Feb/08 05:22           Denis Abramov
# 4979  Resolved             Fixed  30/Jan/09 16:26           Stirling Chow
# 4980  Resolved             Fixed  12/Sep/09 06:45           Denis Abramov
# 4981  Resolved             Fixed  29/Aug/09 06:22              Joe Kutner
# 4982  Resolved             Fixed  28/Feb/08 05:15           Trevor Pounds
# 4983  Resolved             Fixed  28/Feb/08 06:46           Dejan Bosanac
# 4984  Resolved             Fixed  13/Sep/09 10:43          Richard Yarger
# 4985  Resolved             Fixed  10/Apr/08 12:00           Hiram Chirino
# 4986  Resolved             Fixed  29/Aug/09 05:58           Denis Abramov
# 4987  Resolved             Fixed  30/Jan/09 15:34              Sven Panko
# 4988  Resolved             Fixed  07/Apr/08 15:57           Denis Abramov
# 4989  Resolved             Fixed  25/Feb/08 03:24           Hiram Chirino
# 4990  Resolved             Fixed  09/Apr/08 15:44           Joe Fernandez
# 4991    Closed  Cannot Reproduce  09/Jul/11 18:26                    Adam
# 4992  Resolved         Duplicate  10/Jun/09 12:46                    Adam
# 4993  Resolved             Fixed  07/Apr/08 15:58           Trevor Pounds
# 4994  Resolved             Fixed  09/Apr/08 13:26            Rainer Klute
# 4995  Resolved             Fixed  08/Sep/08 17:06           Thomas Buckel
# 4996  Resolved             Fixed  18/Feb/08 12:56            Rainer Klute
# 4997  Resolved             Fixed  18/Feb/08 12:51            Rainer Klute
# 4998  Resolved             Fixed  23/May/08 07:34           Antonio Muñoz
# 4999  Resolved             Fixed  07/Feb/08 10:03         Jason Rosenberg
#
#               Created               Affects Version/s   Fix Version/s
# 0     05/May/17 14:28                          5.14.0          5.15.0
# 1     04/May/17 20:36                          5.14.5  5.15.0, 5.14.6
# 2     03/May/17 16:23                          5.14.1             NaN
# 3     03/May/17 10:28                          5.14.0          5.15.0
# 4     30/Apr/17 20:01                          5.14.0             NaN
# 5     27/Apr/17 10:57                          5.14.0          5.15.0
# 6     26/Apr/17 13:47                          5.14.5             NaN
# 7     26/Apr/17 09:00                          5.11.0             NaN
# 8     25/Apr/17 19:57                          5.14.5             NaN
# 9     25/Apr/17 12:41                             NaN  5.15.0, 5.14.6
# 10    21/Apr/17 21:23                           5.8.0             NaN
# 11    21/Apr/17 14:26                          5.14.4  5.15.0, 5.14.6
# 12    19/Apr/17 12:54                          5.14.3             NaN
# 13    17/Apr/17 08:33                          5.14.4             NaN
# 14    13/Apr/17 08:39                          5.13.4             NaN
# 15    11/Apr/17 03:51                  5.13.0, 5.13.5     Unscheduled
# 16    10/Apr/17 22:16                          5.14.4             NaN
# 17    10/Apr/17 16:38                          5.14.4             NaN
# 18    10/Apr/17 16:13                          5.14.0  5.15.0, 5.14.5
# 19    10/Apr/17 14:45                          5.14.4  5.15.0, 5.14.5
# 20    10/Apr/17 13:39                          5.14.4             NaN
# 21    10/Apr/17 10:47                          5.14.4  5.15.0, 5.14.5
# 22    10/Apr/17 08:44                          5.14.0          5.14.0
# 23    10/Apr/17 07:35  5.10.0, 5.10.1, 5.11.0, 5.13.2             NaN
# 24    04/Apr/17 16:29                          5.14.0          5.15.0
# 25    04/Apr/17 14:02                          5.14.0          5.15.0
# 26    04/Apr/17 11:17                          5.14.0  5.15.0, 5.14.5
# 27    04/Apr/17 09:10                          5.14.0          5.15.0
# 28    31/Mar/17 13:05                          5.14.4  5.15.0, 5.14.5
# 29    30/Mar/17 07:54                          5.14.0             NaN
# ...               ...                             ...             ...
# 4970  05/Mar/08 09:31                           5.0.0    NEEDS_REVIEW
# 4971  03/Mar/08 18:41                             NaN           5.6.0
# 4972  01/Mar/08 04:18                           5.0.0           5.4.0
# 4973  29/Feb/08 23:19                           5.0.0           5.1.0
# 4974  29/Feb/08 21:57                           5.0.0    NEEDS_REVIEW
# 4975  29/Feb/08 21:56                           5.0.0    NEEDS_REVIEW
# 4976  28/Feb/08 20:42      4.0.2, 4.1.0, 4.1.1, 5.0.0           5.5.0
# 4977  25/Feb/08 23:34                           5.0.0           5.1.0
# 4978  25/Feb/08 22:52                           5.0.0           5.1.0
# 4979  25/Feb/08 22:34                           5.1.0           5.3.0
# 4980  25/Feb/08 21:41                           5.1.0           5.3.0
# 4981  25/Feb/08 17:34                           4.1.1           5.3.0
# 4982  25/Feb/08 17:05                             NaN           5.1.0
# 4983  25/Feb/08 11:27                             NaN           5.1.0
# 4984  22/Feb/08 18:33                           5.1.0           5.3.0
# 4985  22/Feb/08 17:02                           5.0.0           5.1.0
# 4986  22/Feb/08 16:28             4.1.1, 5.0.0, 5.1.0           5.3.0
# 4987  22/Feb/08 09:49                           5.0.0           5.3.0
# 4988  22/Feb/08 06:10                           4.1.1           5.1.0
# 4989  20/Feb/08 22:04                           5.0.0           5.1.0
# 4990  20/Feb/08 17:27                           5.0.0           5.1.0
# 4991  20/Feb/08 16:19                           5.2.0    NEEDS_REVIEW
# 4992  20/Feb/08 16:14                           5.2.0           5.3.0
# 4993  20/Feb/08 03:35                           5.0.0           5.1.0
# 4994  18/Feb/08 15:10                           5.1.0           5.1.0
# 4995  17/Feb/08 23:25             4.1.1, 5.0.0, 5.1.0           5.2.0
# 4996  15/Feb/08 09:51                           5.1.0           5.1.0
# 4997  15/Feb/08 03:15                           5.1.0           5.1.0
# 4998  08/Feb/08 08:56                           4.1.1           4.1.2
# 4999  06/Feb/08 16:50                             NaN           5.1.0
#
# [5000 rows x 13 columns]

# %% [markdown]
# ## merge with bug severity database found on issue.apache.org using issue keys

# %%
mask1=(commit_data['Key'].isnull()==False)
mask2 =(commit_data['Key']!="")
df=pd.merge (commit_data[mask1 & mask2], 
            severity[severity['Key'].isnull()==False], 
            how="left",on="Key")
df.tail()
# Out:
#       index_x      sha                date            author  \
# 4113     7903  22474cd 2005-12-21 20:43:50  Hiram R. Chirino
# 4114     7905  75a6b83 2005-12-21 09:31:18      Adrian T. Co
# 4115     7912  dad9a3b 2005-12-20 10:20:22      Adrian T. Co
# 4116     7919  8b1f5a7 2005-12-19 17:43:22    James Strachan
# 4117     7936  639265d 2005-12-15 08:06:44  Hiram R. Chirino
#
#                                                 message  insertions  \
# 4113  Fixed: https://jira.logicblaze.com/jira/browse...         4.0
# 4114  Added a basic mean to query the jmx context. P...       386.0
# 4115               Re-removed old config documentation.         0.0
# 4116  * added test case to demonstrate query-based s...         5.0
# 4117                Re-enable the use of continuations.         2.0
#
#       deletions                                           filename  isTest  \
# 4113        0.0  activemq-core/src/main/java/org/activemq/Activ...       0
# 4114      183.0  activemq-core/src/main/java/org/activemq/broke...       0
# 4115        7.0  activemq-core/src/main/java/org/activemq/broke...       0
# 4116        0.0  activemq-core/src/main/java/org/activemq/Activ...       0
# 4117        2.0  activemq-web/src/java/org/activemq/web/Message...       0
#
#            dateT      ...       Summary  Description Issue Type  Status  \
# 4113  2005-12-21      ...           NaN          NaN        NaN     NaN
# 4114  2005-12-21      ...           NaN          NaN        NaN     NaN
# 4115  2005-12-20      ...           NaN          NaN        NaN     NaN
# 4116  2005-12-19      ...           NaN          NaN        NaN     NaN
# 4117  2005-12-15      ...           NaN          NaN        NaN     NaN
#
#      Resolution Resolved Creator Created  Affects Version/s  Fix Version/s
# 4113        NaN      NaN     NaN     NaN                NaN            NaN
# 4114        NaN      NaN     NaN     NaN                NaN            NaN
# 4115        NaN      NaN     NaN     NaN                NaN            NaN
# 4116        NaN      NaN     NaN     NaN                NaN            NaN
# 4117        NaN      NaN     NaN     NaN                NaN            NaN
#
# [5 rows x 36 columns]

# %%
len(np.unique(severity['Key']))
# Out:
# 4978

# %%
df.shape
# Out:
# (4118, 36)

# %% [markdown]
# ## Finally, merge with OO and traditional metrics based on version and class name

# %% [markdown]
# ### split filename to begin with org/... and match with Class Name of X

# %%
def split_org(x):
    if "org" not in x:
        return x
    else:
        return "org" + re.compile("/org").split(x)[1]
        
df['filename']=df['filename'].apply(lambda x: split_org(x))

# %%
mydata=pd.merge(df, X, how="left", left_on=["filename","Affects Version/s"],right_on=["Class Name","version"])

# %%
mydata.head()
# Out:
#    index_x      sha                date        author  \
# 0        0  2518bde 2017-05-05 14:43:09        gtully
# 1        2  bc879d7 2017-05-04 20:37:53  Timothy Bish
# 2        3  2e2d5dd 2017-05-04 20:37:53  Timothy Bish
# 3        5  2bd3379 2017-05-04 10:08:32        gtully
# 4       10  a0ba0bf 2017-05-03 10:36:06        gtully
#
#                                              message  insertions  deletions  \
# 0  [AMQ-6670] - trap classcast and marshall error...        10.0        2.0
# 1     https://issues.apache.org/jira/browse/AMQ-6669         5.0        0.0
# 2     https://issues.apache.org/jira/browse/AMQ-6669         5.0        0.0
# 3  [AMQ-6068] make full cleanup of the rar manage...         4.0        0.0
# 4  [AMQ-6667] gate cursor cache enablement on a s...        11.0        2.0
#
#                                             filename  isTest       dateT  \
# 0  org/apache/activemq/store/kahadb/KahaDBStore.java       0  2017-05-05
# 1  org/apache/activemq/transport/amqp/AmqpWSTrans...       0  2017-05-04
# 2  org/apache/activemq/transport/amqp/AmqpWSTrans...       0  2017-05-04
# 3        org/apache/activemq/ActiveMQConnection.java       0  2017-05-04
# 4       org/apache/activemq/broker/region/Queue.java       0  2017-05-03
#
#     ...    version  metric_value RSN   Release-Date  #Classes  #Interfaces  \
# 0   ...        NaN           NaN NaN            NaN       NaN          NaN
# 1   ...        NaN           NaN NaN            NaN       NaN          NaN
# 2   ...        NaN           NaN NaN            NaN       NaN          NaN
# 3   ...        NaN           NaN NaN            NaN       NaN          NaN
# 4   ...        NaN           NaN NaN            NaN       NaN          NaN
#
#    #Methods  #Fields   #Size-In-Bytes  release
# 0       NaN      NaN              NaN      NaT
# 1       NaN      NaN              NaN      NaT
# 2       NaN      NaN              NaN      NaT
# 3       NaN      NaN              NaN      NaT
# 4       NaN      NaN              NaN      NaT
#
# [5 rows x 138 columns]
